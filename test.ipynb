# %%
from langchain_openai import ChatOpenAI
import os

os.environ["OPENAI_API_KEY"] = "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"
os.environ["OPENAI_API_BASE"] = "https://api.groq.com/openai/v1"

llm = ChatOpenAI(
    model="meta-llama/llama-4-maverick-17b-128e-instruct",
    temperature=0
)

# %%
response = llm.invoke("Generate SQL for selecting 100 rows from table 'Hello'")
print(response.content)
# Out:
# **SQL Query: Selecting 100 Rows from 'Hello' Table**
#
# ```sql
# SELECT *
# FROM Hello
# LIMIT 100;
# ```
#
# This SQL query will retrieve the first 100 rows from the 'Hello' table. Note that the order of rows is not guaranteed unless you specify an `ORDER BY` clause. If you need a specific order, consider adding it to the query, for example:
#
# ```sql
# SELECT *
# FROM Hello
# ORDER BY column_name
# LIMIT 100;
# ```
#
# Replace `column_name` with the actual column you want to order by.
